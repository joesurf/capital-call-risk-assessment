# %%
import pandas as pd

file_path = 'final_with_ratios_synthetic_distribution.csv'
data = pd.read_csv(file_path)

data.head()
# Out:
#    wealth - salary  wealth - investment gain  wealth - rental income  \
# 0             True                     False                   False
# 1            False                     False                    True
# 2            False                      True                   False
# 3            False                      True                   False
# 4            False                     False                    True
#
#    wealth - business revenue  wealth - inheritance  wealth - others  \
# 0                      False                 False            False
# 1                      False                 False            False
# 2                      False                 False            False
# 3                      False                 False            False
# 4                      False                 False            False
#
#    fund - salary  fund - investment gain  fund - rental income  \
# 0          False                   False                 False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   wealth - salary                 1000 non-null   bool
#  1   wealth - investment gain        1000 non-null   bool
#  2   wealth - rental income          1000 non-null   bool
#  3   wealth - business revenue       1000 non-null   bool
#  4   wealth - inheritance            1000 non-null   bool
#  5   wealth - others                 1000 non-null   bool
#  6   fund - salary                   1000 non-null   bool
#  7   fund - investment gain          1000 non-null   bool
#  8   fund - rental income            1000 non-null   bool
#  9   fund - business revenue         1000 non-null   bool
#  10  fund - inheritance              1000 non-null   bool
#  11  fund - others                   1000 non-null   bool
# ...

# %%
data.describe()
# Out:
#                Age  speed_of_payment       Income  Adjusted Income  \
# count  1000.000000       1000.000000   1000.00000      1000.000000
# mean     49.445000         39.674000   6513.01113      4974.059845
# std      17.876536          9.797741   2178.23466      3064.928916
# min      18.000000          7.000000   2851.20000         0.000000
# 25%      35.000000         33.000000   4787.57500      3475.645000
# 50%      49.500000         40.000000   6183.06500      5042.710000
# 75%      64.000000         46.000000   7738.88000      6880.230000
# max      89.000000         78.000000  12594.00000     12594.000000
#
#        Annual Income  Adjusted Annual Income  Income Multiplier Based on Age  \
# count    1000.000000             1000.000000                     1000.000000
# mean    78156.133560            59688.718140                        2.695000
# std     26138.815917            36779.146997                        0.905149
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting the histograms for Age and Speed of Payment
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Age distribution
axs[0].hist(data['Age'], bins=30, color='blue', edgecolor='black')
axs[0].set_title('Age Distribution')
axs[0].set_xlabel('Age')
axs[0].set_ylabel('Frequency')

# Speed of Payment distribution
axs[1].hist(data['speed_of_payment'], bins=30, color='green', edgecolor='black')
axs[1].set_title('Speed of Payment Distribution')
axs[1].set_xlabel('Speed of Payment')
axs[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Plot histograms for key numerical variables
fig, axs = plt.subplots(3, 2, figsize=(12, 12))

# Plotting Income
axs[0, 0].hist(data['Income'], bins=30, color='blue', edgecolor='black')
axs[0, 0].set_title('Income Distribution')
axs[0, 0].set_xlabel('Income')
axs[0, 0].set_ylabel('Frequency')

# Plotting Annual Income
axs[0, 1].hist(data['Annual Income'], bins=30, color='green', edgecolor='black')
axs[0, 1].set_title('Annual Income Distribution')
axs[0, 1].set_xlabel('Annual Income')
axs[0, 1].set_ylabel('Frequency')

# Plotting Net Worth
axs[1, 0].hist(data['Net Worth'], bins=30, color='purple', edgecolor='black')
axs[1, 0].set_title('Net Worth Distribution')
axs[1, 0].set_xlabel('Net Worth')
axs[1, 0].set_ylabel('Frequency')

# Plotting Net Worth / Total Commitment
axs[1, 1].hist(data['Net Worth / Total Commitment'], bins=30, color='orange', edgecolor='black')
axs[1, 1].set_title('Net Worth / Total Commitment Distribution')
axs[1, 1].set_xlabel('Net Worth / Total Commitment')
axs[1, 1].set_ylabel('Frequency')

# Plotting Income / Total Commitment
axs[2, 0].hist(data['Income / Total Commitment'], bins=30, color='red', edgecolor='black')
axs[2, 0].set_title('Income / Total Commitment Distribution')
axs[2, 0].set_xlabel('Income / Total Commitment')
axs[2, 0].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Calculating the correlation matrix for the numerical columns
numerical_columns = data.select_dtypes(include=['number'])
correlation_matrix = numerical_columns.corr()

# Plotting the correlation heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True, square=True)
plt.title('Correlation Heatmap of Numerical Features')
plt.xticks(rotation=90, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Selecting wealth-related and fund-related boolean columns
wealth_columns = [col for col in data.columns if 'wealth -' in col]
fund_columns = [col for col in data.columns if 'fund -' in col]

# Calculating the counts of True values for wealth-related and fund-related columns
wealth_true_counts = data[wealth_columns].sum() / len(data)
fund_true_counts = data[fund_columns].sum() /len(data)

# Plotting bar charts for Wealth-related and Fund-related True values
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Wealth-related True values
axs[0].bar(wealth_true_counts.index, wealth_true_counts.values, color='blue', edgecolor='black')
axs[0].set_title('Wealth-related True Values')
axs[0].set_ylabel('Percentage')
axs[0].set_xticklabels(wealth_true_counts.index, rotation=45, ha='right')

# Fund-related True values
axs[1].bar(fund_true_counts.index, fund_true_counts.values, color='green', edgecolor='black')
axs[1].set_title('Fund-related True Values')
axs[1].set_ylabel('Percentage')
axs[1].set_xticklabels(fund_true_counts.index, rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/w7/vb_x50hj0vdg_c9lhl4tnp000000gn/T/ipykernel_69887/422652551.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(wealth_true_counts.index, rotation=45, ha='right')
# /var/folders/w7/vb_x50hj0vdg_c9lhl4tnp000000gn/T/ipykernel_69887/422652551.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(fund_true_counts.index, rotation=45, ha='right')

# %%
data[wealth_columns + fund_columns].sum() / len(data)
# Out:
# wealth - salary              0.332
# wealth - investment gain     0.401
# wealth - rental income       0.144
# wealth - business revenue    0.099
# wealth - inheritance         0.075
# wealth - others              0.071
# fund - salary                0.500
# fund - investment gain       0.100
# fund - rental income         0.100
# fund - business revenue      0.100
# fund - inheritance           0.100
# fund - others                0.100
# dtype: float64

# %%
data['Occupation'].value_counts()
# Out:
# Occupation
# 33 Business & Administration Associate Professionals                                        111
# 24 Business & Administration Professionals                                                   80
# 21 Science & Engineering Professionals                                                       74
# 31 Physical & Engineering Science Associate Professionals                                    52
# 12 Administrative & Commercial Managers                                                      51
# 13 Production & Specialised Services Managers                                                47
# 41 General & Keyboard Clerks                                                                 47
# 83 Drivers & Mobile Machinery Operators                                                      47
# 52 Sales Workers                                                                             46
# 51 Personal Service Workers                                                                  37
# ...

# %%
# Plotting the count of occurrences for each industry in a bar chart
industry_counts = data['Industry'].value_counts()

# Creating the bar plot for industry counts
plt.figure(figsize=(10, 6))
plt.bar(industry_counts.index, industry_counts.values, color='purple', edgecolor='black')
plt.title('Industry Distribution')
plt.xlabel('Industry')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
